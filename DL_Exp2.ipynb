# %% [markdown]
# **1.Normal Without any Technique.**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,BatchNormalization
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.datasets import mnist

(X_train,y_train),(X_test,y_test) = mnist.load_data()

X_train = X_train/255.0
X_test = X_test/255.0

X_train = X_train.reshape(-1,784)
X_test =  X_test.reshape(-1,784)

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

model = Sequential()

model.add(Dense(128, activation="relu",input_shape=(784,)))

model.add(Dense(32,activation="relu"))

model.add(Dense(32,activation="relu"))

model.add(Dense(10,activation="softmax"))

model.compile(loss="categorical_crossentropy",optimizer="Adam",metrics=["accuracy"])

learn_history = model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
print(learn_history.history)

plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(learn_history.history['loss'], label='Training Loss')
plt.plot(learn_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(learn_history.history['accuracy'], label='Training Accuracy')
plt.plot(learn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8588 - loss: 0.4780 - val_accuracy: 0.9623 - val_loss: 0.1263
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9690 - loss: 0.1072 - val_accuracy: 0.9676 - val_loss: 0.1057
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9768 - loss: 0.0732 - val_accuracy: 0.9733 - val_loss: 0.0905
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9815 - loss: 0.0601 - val_accuracy: 0.9740 - val_loss: 0.0822
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9861 - loss: 0.0455 - val_accuracy: 0.9695 - val_loss: 0.1104
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9870 - loss: 0.0402 - val_accuracy: 0.9783 - val_loss: 0.0781
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9905 - loss: 0.0296 - val_accuracy: 0.9730 - val_loss: 0.0945
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9918 - loss: 0.0251 - val_accuracy: 0.9737 - val_loss: 0.0996
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9923 - loss: 0.0234 - val_accuracy: 0.9705 - val_loss: 0.1185
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9914 - loss: 0.0251 - val_accuracy: 0.9766 - val_loss: 0.0955
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9938 - loss: 0.0174 - val_accuracy: 0.9769 - val_loss: 0.0972
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9951 - loss: 0.0157 - val_accuracy: 0.9786 - val_loss: 0.0905
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9939 - loss: 0.0172 - val_accuracy: 0.9769 - val_loss: 0.0981
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9952 - loss: 0.0150 - val_accuracy: 0.9796 - val_loss: 0.0918
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9953 - loss: 0.0141 - val_accuracy: 0.9778 - val_loss: 0.1113
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9961 - loss: 0.0119 - val_accuracy: 0.9782 - val_loss: 0.1114
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9965 - loss: 0.0106 - val_accuracy: 0.9787 - val_loss: 0.1163
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9973 - loss: 0.0094 - val_accuracy: 0.9773 - val_loss: 0.1127
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9961 - loss: 0.0114 - val_accuracy: 0.9753 - val_loss: 0.1333
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9959 - loss: 0.0127 - val_accuracy: 0.9774 - val_loss: 0.1284
# {'accuracy': [0.9248166680335999, 0.9681833386421204, 0.9766666889190674, 0.9812999963760376, 0.9846000075340271, 0.9868833422660828, 0.9886666536331177, 0.9901000261306763, 0.9911500215530396, 0.9916999936103821, 0.9930833578109741, 0.9939166903495789, 0.9932500123977661, 0.9946500062942505, 0.9937666654586792, 0.9953166842460632, 0.9955499768257141, 0.9960166811943054, 0.9957333207130432, 0.9955666661262512], 'loss': [0.2560417652130127, 0.10740704089403152, 0.07672400027513504, 0.05878373980522156, 0.048978373408317566, 0.04045053571462631, 0.0352543443441391, 0.029479030519723892, 0.02695826254785061, 0.02471819706261158, 0.020122971385717392, 0.01854746788740158, 0.019061628729104996, 0.01721210964024067, 0.018207665532827377, 0.014208391308784485, 0.013229679316282272, 0.012932110577821732, 0.012673930265009403, 0.013342575170099735], 'val_accuracy': [0.9623000025749207, 0.9675999879837036, 0.9732999801635742, 0.9739999771118164, 0.9695000052452087, 0.9782999753952026, 0.9729999899864197, 0.9736999869346619, 0.9704999923706055, 0.9765999913215637, 0.9768999814987183, 0.978600025177002, 0.9768999814987183, 0.9796000123023987, 0.9778000116348267, 0.9782000184059143, 0.9786999821662903, 0.9772999882698059, 0.9753000140190125, 0.977400004863739], 'val_loss': [0.12634147703647614, 0.10565237700939178, 0.09046708047389984, 0.08220264315605164, 0.1103612557053566, 0.07814904302358627, 0.09447720646858215, 0.0995555967092514, 0.11850503087043762, 0.09550312906503677, 0.09720361232757568, 0.09048169106245041, 0.0980934128165245, 0.0918021947145462, 0.11132550984621048, 0.11143382638692856, 0.1163049191236496, 0.11273252218961716, 0.13326424360275269, 0.12841366231441498]}

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,BatchNormalization,Activation
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.datasets import mnist

(X_train,y_train),(X_test,y_test) = mnist.load_data()

X_train = X_train/255.0
X_test = X_test/255.0

X_train = X_train.reshape(-1,784)
X_test =  X_test.reshape(-1,784)

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

model = Sequential()


model.add(Dense(128,input_shape=(784,)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(10,activation="softmax"))

model.compile(loss="categorical_crossentropy",optimizer="Adam",metrics=["accuracy"])

learn_history = model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test),batch_size=32)
print(learn_history.history)

plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(learn_history.history['loss'], label='Training Loss')
plt.plot(learn_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(learn_history.history['accuracy'], label='Training Accuracy')
plt.plot(learn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8790 - loss: 0.4263 - val_accuracy: 0.9665 - val_loss: 0.1082
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9657 - loss: 0.1153 - val_accuracy: 0.9739 - val_loss: 0.0827
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9756 - loss: 0.0823 - val_accuracy: 0.9761 - val_loss: 0.0745
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9797 - loss: 0.0648 - val_accuracy: 0.9795 - val_loss: 0.0670
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9831 - loss: 0.0547 - val_accuracy: 0.9786 - val_loss: 0.0687
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9844 - loss: 0.0486 - val_accuracy: 0.9771 - val_loss: 0.0752
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.
# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.regularizers import L2
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.datasets import mnist

(X_train,y_train),(X_test,y_test) = mnist.load_data()

X_train = X_train/255.0
X_test = X_test/255.0

X_train = X_train.reshape(-1,784)
X_test =  X_test.reshape(-1,784)

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

model = Sequential()

model.add(Dense(128, activation="relu",input_shape=(784,),kernel_regularizer=L2(0.01)))

model.add(Dense(32,activation="relu",kernel_regularizer=L2(0.01)))

model.add(Dense(32,activation="relu",kernel_regularizer=L2(0.01)))

model.add(Dense(10,activation="softmax"))

model.compile(loss="categorical_crossentropy",optimizer="Adam",metrics=["accuracy"])

learn_history = model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
print(learn_history.history)

plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(learn_history.history['loss'], label='Training Loss')
plt.plot(learn_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(learn_history.history['accuracy'], label='Training Accuracy')
plt.plot(learn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8183 - loss: 1.4322 - val_accuracy: 0.9147 - val_loss: 0.6747
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9157 - loss: 0.6536 - val_accuracy: 0.9034 - val_loss: 0.6298
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9257 - loss: 0.5703 - val_accuracy: 0.9398 - val_loss: 0.5064
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9328 - loss: 0.5193 - val_accuracy: 0.9439 - val_loss: 0.4722
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9375 - loss: 0.4824 - val_accuracy: 0.9432 - val_loss: 0.4492
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9411 - loss: 0.4533 - val_accuracy: 0.9507 - val_loss: 0.4165
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9423 - loss: 0.4326 - val_accuracy: 0.9488 - val_loss: 0.4054
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9429 - loss: 0.4194 - val_accuracy: 0.9464 - val_loss: 0.3994
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9476 - loss: 0.4007 - val_accuracy: 0.9403 - val_loss: 0.4181
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.9479 - loss: 0.3902 - val_accuracy: 0.9515 - val_loss: 0.3712
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9482 - loss: 0.3814 - val_accuracy: 0.9564 - val_loss: 0.3586
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9494 - loss: 0.3754 - val_accuracy: 0.9547 - val_loss: 0.3648
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9483 - loss: 0.3713 - val_accuracy: 0.9537 - val_loss: 0.3560
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9505 - loss: 0.3662 - val_accuracy: 0.9543 - val_loss: 0.3501
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9501 - loss: 0.3594 - val_accuracy: 0.9520 - val_loss: 0.3453
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9472 - loss: 0.3625 - val_accuracy: 0.9530 - val_loss: 0.3460
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9512 - loss: 0.3504 - val_accuracy: 0.9463 - val_loss: 0.3586
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9501 - loss: 0.3531 - val_accuracy: 0.9441 - val_loss: 0.3701
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9498 - loss: 0.3478 - val_accuracy: 0.9470 - val_loss: 0.3543
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9510 - loss: 0.3473 - val_accuracy: 0.9527 - val_loss: 0.3369
# {'accuracy': [0.8829333186149597, 0.9196833372116089, 0.9285666942596436, 0.9340833425521851, 0.9381999969482422, 0.9414833188056946, 0.9435333609580994, 0.9440833330154419, 0.9470666646957397, 0.9482166767120361, 0.9472166895866394, 0.9490500092506409, 0.9490833282470703, 0.9498500227928162, 0.9493499994277954, 0.9490500092506409, 0.9505333304405212, 0.9500166773796082, 0.9503499865531921, 0.9504333138465881], 'loss': [0.9531612992286682, 0.6293944120407104, 0.5554099082946777, 0.5082294344902039, 0.47550469636917114, 0.44877344369888306, 0.427971750497818, 0.4151935279369354, 0.39930304884910583, 0.3887966275215149, 0.384082168340683, 0.37544772028923035, 0.3688732981681824, 0.3650203347206116, 0.3613353371620178, 0.3585158586502075, 0.351984441280365, 0.3509621322154999, 0.34623169898986816, 0.346199095249176], 'val_accuracy': [0.9146999716758728, 0.9034000039100647, 0.9398000240325928, 0.9438999891281128, 0.9431999921798706, 0.9506999850273132, 0.9488000273704529, 0.946399986743927, 0.9402999877929688, 0.9514999985694885, 0.9563999772071838, 0.9546999931335449, 0.9537000060081482, 0.9542999863624573, 0.9520000219345093, 0.953000009059906, 0.9463000297546387, 0.944100022315979, 0.9470000267028809, 0.9527000188827515], 'val_loss': [0.674727201461792, 0.6298466324806213, 0.506443440914154, 0.4722048342227936, 0.4492100179195404, 0.41652828454971313, 0.40543702244758606, 0.39935633540153503, 0.41805240511894226, 0.3712073564529419, 0.35857364535331726, 0.3648163378238678, 0.35599827766418457, 0.3501468896865845, 0.3453383445739746, 0.34597572684288025, 0.35860639810562134, 0.37008652091026306, 0.35427868366241455, 0.336947500705719]}

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.regularizers import L2
from keras.utils import to_categorical
from keras.losses import categorical_crossentropy
from keras.datasets import mnist

(X_train,y_train),(X_test,y_test) = mnist.load_data()

X_train = X_train/255.0
X_test = X_test/255.0

X_train = X_train.reshape(-1,784)
X_test =  X_test.reshape(-1,784)

y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)


model = Sequential()

model.add(Dense(128, activation="relu",input_shape=(784,)))
model.add(Dropout(0.3))

model.add(Dense(32,activation="relu"))
model.add(Dropout(0.3))

model.add(Dense(32,activation="relu"))
model.add(Dropout(0.3))

model.add(Dense(10,activation="softmax"))

model.compile(loss="categorical_crossentropy",optimizer="Adam",metrics=["accuracy"])

learn_history = model.fit(X_train,y_train,epochs=20,validation_data=(X_test,y_test))
print(learn_history.history)

plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(learn_history.history['loss'], label='Training Loss')
plt.plot(learn_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(learn_history.history['accuracy'], label='Training Accuracy')
plt.plot(learn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy (MLP)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6804 - loss: 0.9646 - val_accuracy: 0.9475 - val_loss: 0.1867
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9143 - loss: 0.3356 - val_accuracy: 0.9605 - val_loss: 0.1428
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9312 - loss: 0.2600 - val_accuracy: 0.9631 - val_loss: 0.1359
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9439 - loss: 0.2187 - val_accuracy: 0.9671 - val_loss: 0.1242
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9489 - loss: 0.1944 - val_accuracy: 0.9696 - val_loss: 0.1104
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.